# %%
import xarray as xr

# %%
ssh = xr.open_dataset('/nobackup/csjone15/pleiades_llc_recipes/python_cli_data_export/llc4320_U-V_k0_iter_390528.nc')

# %%
ssh.U.encoding
# Out:
# {'zlib': True,
#  'shuffle': True,
#  'complevel': 1,
#  'fletcher32': False,
#  'contiguous': False,
#  'chunksizes': (1, 5, 1, 60, 60),
#  'source': '/nobackup/csjone15/pleiades_llc_recipes/python_cli_data_export/llc4320_U-V_k0_iter_390528.nc',
#  'original_shape': (1, 90, 1, 2160, 2160),
#  'dtype': dtype('float32'),
#  '_FillValue': nan,
#  'coordinates': 'niter'}

# %%
ssh.U.plot()

# %%
ssh.Eta.plot()

# %%
ssh.time
# Out:
# <xarray.DataArray 'time' (time: 1)>
# array(['2012-01-01T16:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#     niter    (time) int64 ...
#   * time     (time) datetime64[ns] 2012-01-01T16:00:00
